# %%
# %matplotlib inline
import sys
print(sys.version)
import numpy as np
print(np.__version__)
import pandas as pd
print(pd.__version__)
import matplotlib.pyplot as plt
# Out:
# 3.5.2 (default, Oct 11 2016, 04:59:56)
# [GCC 4.2.1 Compatible Apple LLVM 8.0.0 (clang-800.0.38)]
# 1.11.2
# 0.19.0

# %%
df = pd.read_csv('raw_running_data.csv', parse_dates=['Date'])

# %%
df.set_index('Date', inplace=True)

# %%
df['day-of-week'] = df.index.map(lambda x: x.strftime('%A'))

# %%
df['km'] = df.Miles.map(lambda x: x*1.60934)

# %%
df['month'] = df.index.map(lambda x: x.strftime('%B'))

# %%
# pay attention here, join happens on index
temp = pd.DataFrame(index=pd.date_range(df.index.min(), df.index.max()))
df = df.join(temp, how='outer')

# %%
df.Miles.fillna(0, inplace=True)

# %%
df['seconds'] = df.Time.map(get_total_seconds)

# %%
def get_total_seconds(raw_time):
    if str(raw_time) == 'nan': # is np.nan:
        return np.nan # if it's NaN, leave it
    hrs, mins, seconds = str(raw_time).split(':')
    seconds = int(seconds) + 60 * int(mins) + 60 * 60 * int(hrs)
    return seconds    
print(get_total_seconds(df.Time[0]))
# df.Time[0]
# Out:
# nan

# %%
df['minutes'] = df.seconds.map(lambda x: x/60)

# %%
df['month'].value_counts()
# Out:
# August       29
# December     14
# November     13
# September    13
# October      11
# January       1
# Name: month, dtype: int64

# %%
# pd.rolling_mean(df.Miles, window=7).plot()
df.Miles.plot()
df.Miles.rolling(window=7).std().plot()

# %%
df.head(10)
# df.index.min()
# Out:
#             Miles     Time day-of-week        km   month  seconds    minutes
# 2014-08-02   1.70      NaN    Saturday  2.735878  August      NaN        NaN
# 2014-08-03   1.40      NaN      Sunday  2.253076  August      NaN        NaN
# 2014-08-04   2.10      NaN      Monday  3.379614  August      NaN        NaN
# 2014-08-05   0.00      NaN         NaN       NaN     NaN      NaN        NaN
# 2014-08-06   2.38      NaN   Wednesday  3.830229  August      NaN        NaN
# 2014-08-07   2.30      NaN    Thursday  3.701482  August      NaN        NaN
# 2014-08-08   3.40      NaN      Friday  5.471756  August      NaN        NaN
# 2014-08-09   2.50      NaN    Saturday  4.023350  August      NaN        NaN
# 2014-08-10   3.36  0:28:37      Sunday  5.407382  August   1717.0  28.616667
# 2014-08-11   1.67  0:13:07      Monday  2.687598  August    787.0  13.116667
